# %%
import os

os.chdir('..')

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv('assets/wave_height_hourly.csv')

# %%
data.head()
# Out:
#                   time  SignificantWaveHeight
# 0  2016-01-01 00:00:00               6.085000
# 1  2016-01-01 01:00:00               5.989611
# 2  2016-01-01 02:00:00               5.494222
# 3  2016-01-01 03:00:00               5.170778
# 4  2016-01-01 04:00:00               5.362333

# %%
wave = pd.Series(data['SignificantWaveHeight'].values, index = pd.to_datetime(data['time']))
wave.plot()
# Out:
# <Axes: xlabel='time'>

# %%
from src.tde import UnivariateTDE

# %%
# prever o próximo valor com base nos 6 anteriores
wave_tde = UnivariateTDE(wave.diff(), horizon=1, k=6)
wave_tde.head()
# Out:
#         t-5       t-4       t-3       t-2       t-1       t-0       t+1
# 0 -0.095389 -0.495389 -0.323444  0.191556 -0.485778  0.233667 -0.254111
# 1 -0.495389 -0.323444  0.191556 -0.485778  0.233667 -0.254111  0.215056
# 2 -0.323444  0.191556 -0.485778  0.233667 -0.254111  0.215056 -0.087000
# 3  0.191556 -0.485778  0.233667 -0.254111  0.215056 -0.087000  0.434556
# 4 -0.485778  0.233667 -0.254111  0.215056 -0.087000  0.434556 -0.112556

# %%
# separar variáveis explicativas da variável objetivo
X = wave_tde.drop('t+1', axis=1)
y = wave_tde['t+1']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
X_train.head()
# Out:
#         t-5       t-4       t-3       t-2       t-1       t-0
# 0 -0.095389 -0.495389 -0.323444  0.191556 -0.485778  0.233667
# 1 -0.495389 -0.323444  0.191556 -0.485778  0.233667 -0.254111
# 2 -0.323444  0.191556 -0.485778  0.233667 -0.254111  0.215056
# 3  0.191556 -0.485778  0.233667 -0.254111  0.215056 -0.087000
# 4 -0.485778  0.233667 -0.254111  0.215056 -0.087000  0.434556

# %%
y_train.head()
# Out:
# 0   -0.254111
# 1    0.215056
# 2   -0.087000
# 3    0.434556
# 4   -0.112556
# Name: t+1, dtype: float64

# %% [markdown]
# # Estimação de Desempenho

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_absolute_error

from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
cv = TimeSeriesSplit(n_splits=5)

cv_err = []
for tr_idx, ts_idx in cv.split(X_train, y_train):
    print('Training indices:')
    print(tr_idx[-5:])
    X_tr = X_train.values[tr_idx]
    y_tr = y_train.values[tr_idx]

    X_vl = X_train.values[ts_idx]
    y_vl = y_train.values[ts_idx]

    print('Training the model')
    model = Ridge()

    model.fit(X_tr, y_tr)
    print('Making predictions')
    pred = model.predict(X_vl)

    print('Computing error')
    err = mean_absolute_error(y_vl, pred)
    cv_err.append(err)

    
print(cv_err)
# Out:
# Training indices:
# [3494 3495 3496 3497 3498]
# Training the model
# Making predictions
# Computing error
# Training indices:
# [6988 6989 6990 6991 6992]
# Training the model
# Making predictions
# Computing error
# Training indices:
# [10482 10483 10484 10485 10486]
# Training the model
# Making predictions
# Computing error
# Training indices:
# [13976 13977 13978 13979 13980]
# Training the model
# Making predictions
# Computing error
# Training indices:
# [17470 17471 17472 17473 17474]
# Training the model
# Making predictions
# Computing error
# [0.08107471914175518, 0.13180631147430816, 0.08656553595754712, 0.11591728602594027, 0.1407729789655364]

# %%
# erro estimado em validação cruzada
print(f'Average error is: {np.mean(cv_err)}')
# Out:
# Average error is: 0.11122736631301741

# %%
# erro que obtemos no teste
model = Ridge()
model.fit(X_train, y_train)
pred_test = model.predict(X_test)
err_test = mean_absolute_error(y_test, pred_test)
print(f'Test error is: {err_test}')
# Out:
# Test error is: 0.10236054786737814

# %% [markdown]
# # Seleção de Modelo

# %%
model_list = {
    'Ridge': Ridge(),
    'Lasso': Lasso(),
    'RandomForestRegressor': RandomForestRegressor(n_estimators=10),
    'DecisionTreeRegressor': DecisionTreeRegressor(),
    'KNeighborsRegressor': KNeighborsRegressor(),
}

from sklearn.model_selection import cross_val_score

# %%
err_by_method = {}
for method in model_list:
    print(f'Running model: {method}')
    cv_error = cross_val_score(model_list[method],
                               X_train,
                               y_train,
                               cv=cv,
                               scoring='neg_mean_absolute_error')

    err_by_method[method] = -np.mean(cv_error)
# Out:
# Running model: Ridge
# Running model: Lasso
# Running model: RandomForestRegressor
# Running model: DecisionTreeRegressor
# Running model: KNeighborsRegressor

# %%
pd.Series(err_by_method).plot.bar()
# Out:
# <Axes: >

# %%
from pprint import pprint
pprint(err_by_method)
# Out:
# {'DecisionTreeRegressor': 0.16432126037177736,
#  'KNeighborsRegressor': 0.12118358152115039,
#  'Lasso': 0.11472092284026729,
#  'RandomForestRegressor': 0.1205587426450911,
#  'Ridge': 0.11122736631301744}

# %% [markdown]
# # Seleção de Parâmetros

# %%
from sklearn.model_selection import GridSearchCV


parameters = {'weights': ['uniform', 'distance'],
              'n_neighbors': [1, 5, 10]}

# %%
model = KNeighborsRegressor()
cv = TimeSeriesSplit(n_splits=5)

grid_search = GridSearchCV(estimator=model,
                           param_grid=parameters,
                           cv=cv, 
                           refit=True)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#              estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': [1, 5, 10],
#                          'weights': ['uniform', 'distance']})

# %%
grid_search.best_estimator_
# Out:
# KNeighborsRegressor(n_neighbors=10)

# %%
pred_test_best = grid_search.predict(X_test)
err_test = mean_absolute_error(y_test, pred_test_best)
print(f'Test error is: {err_test}')
# Out:
# Test error is: 0.10670454577065293
